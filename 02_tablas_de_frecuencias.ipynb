# %% [markdown]
# # Tarea
# ## Usar la funcion download_data dentro de un notebook de jupyter

# %%
# Import pandas 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Data frame 
df = pd.read_csv('tmp/Ejemplo_01_Laptops_Dataset.csv')

# %%
df.head()
# Out:
#      brand                       name     price  spec_score  user_votes  \
# 0       hp  Victus 15-fb0157AX Gaming   49800.0        70.0        97.0
# 1   xiaomi    Redmi G Pro 2024 Gaming  102990.0        78.0        71.0
# 2    tecno                Megabook T1   23990.0        56.0       177.0
# 3  samsung        Galaxy Book2 Pro 13   62990.0        60.0      1511.0
# 4    apple   MacBook Air 2020 MGND3HN   79990.0        43.0     20380.0
#
#    user_rating           os  utility: Business  utility: Everyday Use  \
# 0          4.3   windows 11                  0                      0
# 1          4.3   windows 11                  0                      0
# 2          4.4   windows 11                  0                      0
# 3          4.5   windows 11                  0                      1
# 4          4.7          mac                  0                      0
#
#    utility: Performance  ...  processor_gen  processor_brand  processor_core  \
# 0                     0  ...            5.0              amd         Ryzen 5
# 1                     0  ...           14.0            intel         Core i9
# 2                     1  ...           11.0            intel         Core i3
# 3                     0  ...           12.0            intel         Core i5
# 4                     1  ...            1.0            apple             NaN
#
#    base_processor_speed_GHz  turbo_processor_speed_GHz  no_cores  \
# 0                       3.3                        4.2       6.0
# 1                       2.2                        5.8      24.0
# 2                       3.0                        4.1       2.0
# 3                       1.7                        4.4      12.0
# 4                       NaN                        3.2       8.0
#
#    cache_memory_mb graphics_brand  rom_capacity_gb internal_memory_gb
# 0             16.0            amd              8.0              512.0
# 1             36.0         nvidia             16.0             1024.0
# 2              6.0          intel              8.0              512.0
# 3             12.0          intel             16.0              512.0
# 4              NaN          apple              8.0              256.0
#
# [5 rows x 34 columns]

# %%
# Determinar rango de datos
rango = df['price'].max() - df['price'].min()
print(rango)
# Out:
# 591990.0

# %%
n_clases = 1 * 3.322 * (df['price'].count() **(1/3))
print(n_clases)
# Out:
# 33.18674672452235

# %%
# Determinar la amplitud 
amplitud = rango / n_clases
print(amplitud)
# Out:
# 17838.14499547094

# %%
# Definir limites de los intervalos 
limites = [df['price'].min() + i * amplitud for i in range(int(n_clases) + 1)]
print(limites)
# Out:
# [np.float64(8000.0), np.float64(25838.14499547094), np.float64(43676.28999094188), np.float64(61514.434986412816), np.float64(79352.57998188375), np.float64(97190.7249773547), np.float64(115028.86997282563), np.float64(132867.01496829657), np.float64(150705.1599637675), np.float64(168543.30495923845), np.float64(186381.4499547094), np.float64(204219.59495018033), np.float64(222057.73994565126), np.float64(239895.8849411222), np.float64(257734.02993659314), np.float64(275572.1749320641), np.float64(293410.319927535), np.float64(311248.46492300596), np.float64(329086.6099184769), np.float64(346924.75491394784), np.float64(364762.8999094188), np.float64(382601.0449048897), np.float64(400439.18990036065), np.float64(418277.3348958316), np.float64(436115.47989130253), np.float64(453953.62488677347), np.float64(471791.7698822444), np.float64(489629.91487771535), np.float64(507468.0598731863), np.float64(525306.2048686573), np.float64(543144.3498641282), np.float64(560982.494859599), np.float64(578820.63985507), np.float64(596658.784850541)]

# %%
# Definir los puntos medios 
marcas = [(limites[i] + limites[i+1]) / 2 for i in range(int(n_clases))]
print(marcas)
# Out:
# [np.float64(16919.07249773547), np.float64(34757.21749320641), np.float64(52595.36248867735), np.float64(70433.50748414829), np.float64(88271.65247961922), np.float64(106109.79747509016), np.float64(123947.9424705611), np.float64(141786.08746603204), np.float64(159624.23246150298), np.float64(177462.37745697392), np.float64(195300.52245244486), np.float64(213138.6674479158), np.float64(230976.81244338673), np.float64(248814.95743885767), np.float64(266653.10243432864), np.float64(284491.2474297995), np.float64(302329.3924252705), np.float64(320167.5374207414), np.float64(338005.6824162124), np.float64(355843.8274116833), np.float64(373681.9724071543), np.float64(391520.11740262515), np.float64(409358.26239809615), np.float64(427196.40739356703), np.float64(445034.552389038), np.float64(462872.6973845089), np.float64(480710.8423799799), np.float64(498548.9873754508), np.float64(516387.1323709218), np.float64(534225.2773663928), np.float64(552063.4223618635), np.float64(569901.5673573345), np.float64(587739.7123528055)]

# %%
# Tabla de frecuencia con datos numericos de los limites 
tabla_frecuencias_num = pd.DataFrame({
    'Intervalo_de_clases': [f'({round(limites[i], 2)} - {round(limites[i + 1], 2)})' for i in range(int(n_clases))],
    'Marca_de_clase': [round(marcas[1], 2) for i in range(int(n_clases))],
    'Frecuencia_absoluta': [((df['price'] >= limites[i]) & (df['price'] < limites[i + 1])).sum() for i in range(int(n_clases))],
    'Frecuencia_relativa': [((df['price'] >= limites[i]) & (df['price'] < limites[i + 1])).sum() / df['price'].count() for i in range(int(n_clases))]
})

tabla_frecuencias_num
# Out:
#         Intervalo_de_clases  Marca_de_clase  Frecuencia_absoluta  \
# 0       (8000.0 - 25838.14)        34757.22                   44
# 1     (25838.14 - 43676.29)        34757.22                  183
# 2     (43676.29 - 61514.43)        34757.22                  240
# 3     (61514.43 - 79352.58)        34757.22                  169
# 4     (79352.58 - 97190.72)        34757.22                  114
# 5    (97190.72 - 115028.87)        34757.22                   72
# 6   (115028.87 - 132867.01)        34757.22                   31
# 7   (132867.01 - 150705.16)        34757.22                   33
# 8    (150705.16 - 168543.3)        34757.22                   26
# 9    (168543.3 - 186381.45)        34757.22                   17
# 10  (186381.45 - 204219.59)        34757.22                   13
# 11  (204219.59 - 222057.74)        34757.22                    5
# 12  (222057.74 - 239895.88)        34757.22                    9
# 13  (239895.88 - 257734.03)        34757.22                    5
# 14  (257734.03 - 275572.17)        34757.22                    3
# 15  (275572.17 - 293410.32)        34757.22                    7
# 16  (293410.32 - 311248.46)        34757.22                    6
# 17  (311248.46 - 329086.61)        34757.22                    1
# 18  (329086.61 - 346924.75)        34757.22                    3
# 19   (346924.75 - 364762.9)        34757.22                    3
# 20   (364762.9 - 382601.04)        34757.22                    2
# 21  (382601.04 - 400439.19)        34757.22                    4
# 22  (400439.19 - 418277.33)        34757.22                    1
# 23  (418277.33 - 436115.48)        34757.22                    0
# 24  (436115.48 - 453953.62)        34757.22                    2
# 25  (453953.62 - 471791.77)        34757.22                    1
# 26  (471791.77 - 489629.91)        34757.22                    0
# 27  (489629.91 - 507468.06)        34757.22                    1
# 28   (507468.06 - 525306.2)        34757.22                    1
# 29   (525306.2 - 543144.35)        34757.22                    0
# 30  (543144.35 - 560982.49)        34757.22                    0
# 31  (560982.49 - 578820.64)        34757.22                    0
# 32  (578820.64 - 596658.78)        34757.22                    0
#
#     Frecuencia_relativa
# 0              0.044132
# 1              0.183551
# 2              0.240722
# 3              0.169509
# 4              0.114343
# 5              0.072217
# 6              0.031093
# 7              0.033099
# 8              0.026078
# 9              0.017051
# 10             0.013039
# 11             0.005015
# 12             0.009027
# 13             0.005015
# 14             0.003009
# 15             0.007021
# 16             0.006018
# 17             0.001003
# 18             0.003009
# 19             0.003009
# 20             0.002006
# 21             0.004012
# 22             0.001003
# 23             0.000000
# 24             0.002006
# 25             0.001003
# 26             0.000000
# 27             0.001003
# 28             0.001003
# 29             0.000000
# 30             0.000000
# 31             0.000000
# 32             0.000000

# %%
# Tabla de frecuencias 
tabla_frecuencias_num.head().sort_values(by='Frecuencia_absoluta', ascending=False)
# Out:
#      Intervalo_de_clases  Marca_de_clase  Frecuencia_absoluta  \
# 2  (43676.29 - 61514.43)        34757.22                  240
# 1  (25838.14 - 43676.29)        34757.22                  183
# 3  (61514.43 - 79352.58)        34757.22                  169
# 4  (79352.58 - 97190.72)        34757.22                  114
# 0    (8000.0 - 25838.14)        34757.22                   44
#
#    Frecuencia_relativa
# 2             0.240722
# 1             0.183551
# 3             0.169509
# 4             0.114343
# 0             0.044132

# %% [markdown]
# # Visualizacion

# %%
# Configuracion de histograma 
plt.figure(figsize=(10,6))
plt.hist(df['price'], bins=32, color='skyblue', edgecolor='black', alpha=0.7)

# Etiquetas / titulos
plt.title('Histograma de precios de laptops :)')
plt.xlabel('precio')
plt.ylabel('frecuencia')
plt.grid(axis='y')

# Mostrar histograma 
plt.show()

# %%
# Ejemplo
eje_x = [1, 2, 3, 4, 5]
eje_y = [120, 210, 34, 42, 500]

plt.plot(eje_x, eje_y)

plt.grid(axis='y')

plt.show()
